# %% [markdown]
# # Thesis experiment pipeline
# Edit only Cell 1 to switch datasets.

# %%
from thesis_pipeline import *
DATASET={'name':'medical_mcq','path':'../data/medical_mcq_example.csv','columns':{'instruction':'instruction','input':'input','gold':'output'}}
pipeline=initialize_thesis(DATASET,RUN_MODE='test',GLOBAL_SEED=42)
print('Dataset ready:',pipeline.bundle.dataset_name)

# %%
single_results=run_single_baselines()
single_results

# %%
agreement_results=run_agreement_experiments()
agreement_results

# %%
selection=select_best_agreement_method()
selection

# %%
final_results=run_final_comparison()
final_results

# %%
build_thesis_outputs()
